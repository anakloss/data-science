# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %% [markdown]
# # STACK TECNOLOGICO DEL DS
#
# ![image.png](attachment:b78f3930-1000-421c-a051-dbe022119ff8.png)
#
# ## Base de datos
# Es un conjunto de datos pertenecientes a un mismo contexto y almacenados sistemáticamente para su posterior uso. Se dividen en:
# * Bases de datos Relacionales - SQL
# * Bases de datos No Relacionales - No SQL
#
# RDBMS = Gestión de bases de datos relaciones
#
# ### Ventajas y Desventajas
# ![image.png](attachment:b25a6f88-68bb-4a76-9541-0a34a7c1383b.png)
# ![image.png](attachment:bb39ac08-5ebd-414c-b1fa-5361affb71b5.png)

# %% [markdown]
# # 1° Entrega del Trabajo Final
# ![image.png](attachment:3a88c9ac-34e0-4d0b-9771-56e105229076.png)
# ![image.png](attachment:1ae38f7e-8896-4e36-8862-30bdb6002817.png)
# ![image.png](attachment:9f8d0fd4-583c-498d-b79c-f53ff4d8df45.png)
